# %%
import random
for _ in range(7):
    print(random.randint(1,49))
# Out:
# 44
# 32
# 15
# 41
# 48
# 16
# 13

# %%
import random
loto=set()
while(len(loto)<7):
    loto.add(random.randint(1,49))
sort_loto = sorted(loto)
for item in sort_loto:
    print(item,end=" ")
# Out:
# 12 13 24 25 29 33 42

# %%
import requests

# %%
import requests

url = "https://raw.githubusercontent.com/roberthsu2003/PythonForDataAnalysis/master/%E6%AA%94%E6%A1%88%E5%AD%98%E5%8F%96/%E5%80%8B%E8%82%A1%E6%97%A5%E6%88%90%E4%BA%A4%E8%B3%87%E8%A8%8A.csv"
response = requests.get(url)

if response.ok:
    print("下載完成")
    print("下載內容:")
    content = response.text
else:
    print("下載失敗")
# Out:
# 下載完成
# 下載內容:

# %%
file=open('單日個股成交資訊.csv',mode='w',encoding='utf-8',newline='')
file.write(content)
file.close()
# Out:
# Bad pipe message: %s [b'\xf2\xacc\xe4y\xbd9[\x0eX\xce\xc5\xf5#\xd4\x9a\x95\xaa \xbag\xc8\x92\xa9\xee\x98\x96\xe6\x12x\xe1(\x8a\xb2\xb6\tL-(\xbf \x90\xaa9\xa8\x93\xc3oCK\x05\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t', b'\x08\x0b\x08\x04\x08\x05\x08']
# Bad pipe message: %s [b'\x01\x05\x01\x06\x01']
# ...
