# %%
import requests
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %%
import pandas as pd

dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame
# Out:
#                            sna  tot  sbi   sarea                 mday
# 0           YouBike2.0_捷運科技大樓站   28    1     大安區  2023-05-27 13:35:14  \
# 1       YouBike2.0_復興南路二段273號前   21    0     大安區  2023-05-27 13:17:22
# 2         YouBike2.0_國北教大實小東側門   16    2     大安區  2023-05-27 13:33:15
# 3            YouBike2.0_和平公園東側   11    0     大安區  2023-05-27 13:34:04
# 4         YouBike2.0_辛亥復興路口西北側   16    3     大安區  2023-05-27 13:35:14
# ...                        ...  ...  ...     ...                  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   21    臺大專區  2023-05-27 13:26:19
# 1276        YouBike2.0_臺大黑森林西側   20    8    臺大專區  2023-05-27 13:35:15
# 1277        YouBike2.0_臺大獸醫館南側   24    9    臺大專區  2023-05-27 13:26:19
# 1278      YouBike2.0_臺大新體育館東南側   40    2    臺大專區  2023-05-27 13:35:15
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    3  臺大公館校區  2023-05-27 12:56:16
#
#                  ar  bemp act
# 0       復興南路二段235號前    24   1
# 1      復興南路二段273號西側    21   1
# 2       和平東路二段96巷7號    13   1
# 3     和平東路二段118巷33號    11   1
# 4        復興南路二段368號    13   1
# ...             ...   ...  ..
# 1275       臺大圖書館西南側     9   1
# 1276        臺大霖澤館南側    11   1
# 1277       臺大獸醫系館南側    15   1
# 1278        臺大體育館東側    38   1
# 1279       明達館北側前空地    14   1
#
# [1280 rows x 8 columns]

# %%
dataFrame[['sna', 'tot', 'sbi']]
# Out:
#                            sna  tot  sbi
# 0           YouBike2.0_捷運科技大樓站   28    1
# 1       YouBike2.0_復興南路二段273號前   21    0
# 2         YouBike2.0_國北教大實小東側門   16    2
# 3            YouBike2.0_和平公園東側   11    0
# 4         YouBike2.0_辛亥復興路口西北側   16    3
# ...                        ...  ...  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   21
# 1276        YouBike2.0_臺大黑森林西側   20    8
# 1277        YouBike2.0_臺大獸醫館南側   24    9
# 1278      YouBike2.0_臺大新體育館東南側   40    2
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    3
#
# [1280 rows x 3 columns]

# %%
dataFrame[52:80]
# Out:
#                            sna  tot  sbi sarea                 mday
# 52    YouBike2.0_捷運臺電大樓站(2號出口)   15    4   大安區  2023-05-27 13:30:39  \
# 53           YouBike2.0_和平金山路口   45   13   大安區  2023-05-27 13:35:14
# 54           YouBike2.0_和平龍泉街口   34    4   大安區  2023-05-27 13:34:14
# 55           YouBike2.0_和平泰順街口    9    7   大安區  2023-05-27 13:13:14
# 56      YouBike2.0_臺灣師範大學(圖書館)   40   18   大安區  2023-05-27 13:35:14
# 57      YouBike2.0_捷運古亭站(6號出口)   60   23   大安區  2023-05-27 13:32:14
# 58      YouBike2.0_捷運古亭站(5號出口)   14    3   大安區  2023-05-27 13:35:14
# 59      YouBike2.0_臺北市立圖書館(總館)   45    6   大安區  2023-05-27 13:34:14
# 60        YouBike2.0_新生和平路口東北側   38    0   大安區  2023-05-27 13:35:04
# 61        YouBike2.0_建國和平路口西北側   44   31   大安區  2023-05-27 13:35:14
# 62             YouBike2.0_金華公園   35    4   大安區  2023-05-27 13:33:15
# 63      YouBike2.0_捷運東門站(3號出口)   15    2   大安區  2023-05-27 13:35:14
# 64             YouBike2.0_金甌女中   12    8   大安區  2023-05-27 13:17:32
# 65             YouBike2.0_金杭公園   20   10   大安區  2023-05-27 13:30:39
# 66           YouBike2.0_愛國金山路口   33   22   大安區  2023-05-27 13:28:14
# 67    YouBike2.0_敦化南路二段293巷口南側   14    4   大安區  2023-05-27 13:31:15
# 68           YouBike2.0_敦化基隆路口   29    1   大安區  2023-05-27 13:15:14
# 69       YouBike2.0_安和路二段181巷口   17    1   大安區  2023-05-27 13:25:15
# 70  YouBike2.0_臨江街夜市(通化街101巷口)   30    1   大安區  2023-05-27 13:26:19
# 71       YouBike2.0_臨江街夜市(基隆路)   17    2   大安區  2023-05-27 13:35:14
# 72       YouBike2.0_台北科技大學億光大樓   46    1   大安區  2023-05-27 13:30:39
# 73      YouBike2.0_新生南路一段119巷口   33   11   大安區  2023-05-27 13:35:14
# 74        YouBike2.0_幸安國小(仁愛路)   16   10   大安區  2023-05-27 13:35:14
# 75             YouBike2.0_民榮公園   15    0   大安區  2023-04-20 07:22:04
# 76      YouBike2.0_復興南路1段340巷口   38   30   大安區  2023-05-27 13:25:15
# 77           YouBike2.0_建國濟南路口   29   21   大安區  2023-05-27 13:34:14
# 78    YouBike2.0_捷運忠孝復興站(2號出口)   43   34   大安區  2023-05-27 13:35:14
# 79      YouBike2.0_捷運大安站(4號出口)   13    0   大安區  2023-05-27 13:35:04
#
#                           ar  bemp act
# 52     辛亥路一段/羅斯福路三段口北側(辛亥路側)    11   1
# 53          和平東路一段/金山南路二段西南側    32   1
# 54            和平東路一段/龍泉街口西南側    29   1
# 55            和平東路一段/泰順街口東南側     2   1
# 56               和平東路一段129號前    18   1
# 57                羅斯福路二段41號前    37   1
# 58                和平東路一段19號前    11   1
# 59   建國南路二段/建國南路二段151巷(橋下空間)    38   1
# 60         新生南路二段與和平東路二段口東北側    37   1
# 61         建國南路二段與和平東路二段口西北側    13   1
# 62                 金華街249號對面    29   1
# 63                信義路二段128號前    13   1
# 64           信義路二段與杭州南路二段東南側     3   1
# 65     愛國東路21巷與杭州南路二段25巷口東南側    10   1
# 66           愛國東路與杭州南路二段口西南側     8   1
# 67             敦化南路二段293巷口南側    10   1
# 68                敦化南路二段218號    26   1
# 69                 安和路二段185號    16   1
# 70                   通化街111號    27   1
# 71                 基隆路二段108號    12   1
# 72                 忠孝東路三段81號    44   1
# 73                新生南路一段113號    20   1
# 74                  仁愛路三段22號     5   1
# 75           建國南路一段304巷45號南側    15   0
# 76       復興南路一段信義路三段147巷45弄口     7   1
# 77        建國南路一段/濟南路三段口(東南側)     8   1
# 78  復興南路一段/仁愛路三段123巷13弄(西北側)     7   1
# 79                信義路4段6號(前)    11   1

# %%
dataFrame.loc[100:120,['sna','sarea']]
# Out:
#                             sna sarea
# 100  YouBike2.0_捷運大安森林公園站(5號出口)   大安區
# 101           YouBike2.0_信義建國路口   大安區
# 102             YouBike2.0_東豐公園   大安區
# 103     YouBike2.0_德安公園(四維路66巷)   大安區
# 104    YouBike2.0_捷運忠孝復興站(5號出口)   大安區
# 105    YouBike2.0_捷運忠孝敦化站(2號出口)   大安區
# 106    YouBike2.0_捷運忠孝敦化站(7號出口)   大安區
# 107          YouBike2.0_瑞安街208巷   大安區
# 108          YouBike2.0_樂利路21巷口   大安區
# 109  YouBike2.0_捷運科技大樓站(台北教育大學)   大安區
# 110   YouBike2.0_捷運國父紀念館站(2號出口)   大安區
# 111             YouBike2.0_仁愛醫院   大安區
# 112    YouBike2.0_捷運信義安和站(4號出口)   大安區
# 113             YouBike2.0_成功國宅   大安區
# 114           YouBike2.0_仁愛延吉街口   大安區
# 115    YouBike2.0_捷運信義安和站(1號出口)   大安區
# 116      YouBike2.0_敦化南路二段103巷口   大安區
# 117      YouBike2.0_復興南路二段128巷口   大安區
# 118         YouBike2.0_和平東建國南路口   大安區
# 119             YouBike2.0_芳蘭山莊   大安區
# 120      YouBike2.0_復興南路一段126巷口   大安區
